# %%
pip install langchain-ollama
# Out:
# ...
#
# ...

# %%
#for chat conersation 
from langchain_ollama import ChatOllama
llm=ChatOllama(
    model="qwen3:4b",
    temperature=0)
response=llm.invoke("explain the concept of quantum entanglement in  one sentence")
print(response.content)
# Out:
# Quantum entanglement occurs when two or more particles become intrinsically linked such that the quantum state of one instantly influences the state of another, regardless of the distance separating them—without any classical communication.

# %%
#for non chat purpose

from langchain_ollama import OllamaLLM
llm=OllamaLLM(
    model="qwen3:4b")
response=llm.invoke("explain the concept of quantum entanglement in  one sentence")
print(response.content)
