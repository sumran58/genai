# %%
from langgraph.graph import StateGraph,START,END
from dotenv import load_dotenv
from typing import TypedDict

from langchain_groq import ChatGroq

from langgraph.checkpoint.memory import InMemorySaver

# %%
load_dotenv()
llm=ChatGroq(model="openai/gpt-oss-120b")

# %%
class JokeState(TypedDict):
    topic:str
    joke:str
    explanation:str

# %%
def generate_joke(state:JokeState):
    prompt=f'generate a joke on the topic {state["topic"]}'
    response=llm.invoke(prompt).content
    return {'joke':response}

# %%
def generate_explanation(state:JokeState):
    prompt=f'write an explanation for the joke- {state["joke"]}'
    response=llm.invoke(prompt).content
    return {'explanation':response}

# %%
graph=StateGraph(JokeState)

graph.add_node("generate_joke",generate_joke)
graph.add_node("generate_explanation",generate_explanation)

graph.add_edge(START,'generate_joke')
graph.add_edge('generate_joke','generate_explanation')
graph.add_edge('generate_explanation',END)

checkpointer=InMemorySaver()

workflow=graph.compile(checkpointer=checkpointer)

# %%
config1={'configurable':{"thread_id":"1"}}
workflow.invoke({'topic':"pizza"},config=config1)
# Out:
# {'topic': 'pizza',
#  'joke': 'Why did the pizza apply for a job?\n\nBecause it wanted to get a *slice* of the action and finally stop feeling so *crust*‑y! 🍕😄',
#  'explanation': '**What the joke is playing with**\n\n1. **“Slice of the action”**  \n   *Slice* is a literal part of a pizza (a piece you eat). In everyday English, “a slice of the action” is a playful way of saying “a share of what’s going on” or “a piece of the excitement.” The joke swaps the literal pizza‑slice meaning for the idiomatic expression, so the pizza “applies for a job” to get its own *slice* of the action.\n\n2. **“Crust‑y”**  \n   The word *crust* is the outer, baked part of a pizza. Adding the “‑y” makes the adjective *crust‑y*, which sounds like “crusty.” In slang, “crusty” can describe someone who’s rough, bitter, or a bit down‑and‑out. The joke pretends the pizza feels “crust‑y” (like it’s just a hard crust) and wants to stop feeling that way.\n\n3. **The overall picture**  \n   - **Why would a pizza look for a job?** Because it wants more than just being a tasty snack; it wants a “share” of something bigger—hence the “slice of the action.”  \n   - **Why does it want to stop feeling crust‑y?** It’s a pun on the pizza’s literal crust and the feeling of being “crusty” (unhappy or rough). By getting a job, the pizza hopes to become “fresh” and “full‑filled” rather than just a dry crust.\n\n4. **Why it’s funny**  \n   - **Personification:** The pizza is given human motives (looking for work, feeling emotions).  \n   - **Wordplay:** The punchline hinges on two puns—*slice* (both a pizza piece and a share) and *crust‑y* (both the pizza’s outer layer and a slang feeling).  \n   - **Surprise:** We expect a typical job‑related reason (money, experience), but the answer flips back to pizza‑specific language, catching the listener off‑guard in a light‑hearted way.\n\n**Bottom line:** The joke works because it treats a pizza like a person who wants a “slice” (share) of excitement and wants to stop being just a “crust‑y” (hard, bitter) piece—mixing culinary terms with everyday idioms for a quick, cheesy laugh. 🍕😄'}

# %%
workflow.get_state(config1)
# Out:
# StateSnapshot(values={'topic': 'pizza', 'joke': 'Why did the pizza apply for a job?\n\nBecause it wanted to get a *slice* of the action and finally stop feeling so *crust*‑y! 🍕😄', 'explanation': '**What the joke is playing with**\n\n1. **“Slice of the action”**  \n   *Slice* is a literal part of a pizza (a piece you eat). In everyday English, “a slice of the action” is a playful way of saying “a share of what’s going on” or “a piece of the excitement.” The joke swaps the literal pizza‑slice meaning for the idiomatic expression, so the pizza “applies for a job” to get its own *slice* of the action.\n\n2. **“Crust‑y”**  \n   The word *crust* is the outer, baked part of a pizza. Adding the “‑y” makes the adjective *crust‑y*, which sounds like “crusty.” In slang, “crusty” can describe someone who’s rough, bitter, or a bit down‑and‑out. The joke pretends the pizza feels “crust‑y” (like it’s just a hard crust) and wants to stop feeling that way.\n\n3. **The overall picture**  \n   - **Why would a pizza look for a job?** Because it wants more than just being a tasty snack; it wants a “share” of something bigger—hence the “slice of the action.”  \n   - **Why does it want to stop feeling crust‑y?** It’s a pun on the pizza’s literal crust and the feeling of being “crusty” (unhappy or rough). By getting a job, the pizza hopes to become “fresh” and “full‑filled” rather than just a dry crust.\n\n4. **Why it’s funny**  \n   - **Personification:** The pizza is given human motives (looking for work, feeling emotions).  \n   - **Wordplay:** The punchline hinges on two puns—*slice* (both a pizza piece and a share) and *crust‑y* (both the pizza’s outer layer and a slang feeling).  \n   - **Surprise:** We expect a typical job‑related reason (money, experience), but the answer flips back to pizza‑specific language, catching the listener off‑guard in a light‑hearted way.\n\n**Bottom line:** The joke works because it treats a pizza like a person who wants a “slice” (share) of excitement and wants to stop being just a “crust‑y” (hard, bitter) piece—mixing culinary terms with everyday idioms for a quick, cheesy laugh. 🍕😄'}, next=(), config={'configurable': {'thread_id': '1', 'checkpoint_ns': '', 'checkpoint_id': '1f19de96-a58b-6b48-8002-457e6c1fafa8'}}, metadata={'source': 'loop', 'step': 2, 'parents': {}}, created_at='2026-08-22T05:22:06.233684+00:00', parent_config={'configurable': {'thread_id': '1', 'checkpoint_ns': '', 'checkpoint_id': '1f19de96-9580-64fe-8001-5261fb8d6a31'}}, tasks=(), interrupts=())

# %%
list(workflow.get_state_history(config1))
# Out:
# [StateSnapshot(values={'topic': 'pizza', 'joke': 'Why did the pizza apply for a job?\n\nBecause it wanted to get a *slice* of the action and finally stop feeling so *crust*‑y! 🍕😄', 'explanation': '**What the joke is playing with**\n\n1. **“Slice of the action”**  \n   *Slice* is a literal part of a pizza (a piece you eat). In everyday English, “a slice of the action” is a playful way of saying “a share of what’s going on” or “a piece of the excitement.” The joke swaps the literal pizza‑slice meaning for the idiomatic expression, so the pizza “applies for a job” to get its own *slice* of the action.\n\n2. **“Crust‑y”**  \n   The word *crust* is the outer, baked part of a pizza. Adding the “‑y” makes the adjective *crust‑y*, which sounds like “crusty.” In slang, “crusty” can describe someone who’s rough, bitter, or a bit down‑and‑out. The joke pretends the pizza feels “crust‑y” (like it’s just a hard crust) and wants to stop feeling that way.\n\n3. **The overall picture**  \n   - **Why would a pizza look for a job?** Because it wants more than just being a tasty snack; it wants a “share” of something bigger—hence the “slice of the action.”  \n   - **Why does it want to stop feeling crust‑y?** It’s a pun on the pizza’s literal crust and the feeling of being “crusty” (unhappy or rough). By getting a job, the pizza hopes to become “fresh” and “full‑filled” rather than just a dry crust.\n\n4. **Why it’s funny**  \n   - **Personification:** The pizza is given human motives (looking for work, feeling emotions).  \n   - **Wordplay:** The punchline hinges on two puns—*slice* (both a pizza piece and a share) and *crust‑y* (both the pizza’s outer layer and a slang feeling).  \n   - **Surprise:** We expect a typical job‑related reason (money, experience), but the answer flips back to pizza‑specific language, catching the listener off‑guard in a light‑hearted way.\n\n**Bottom line:** The joke works because it treats a pizza like a person who wants a “slice” (share) of excitement and wants to stop being just a “crust‑y” (hard, bitter) piece—mixing culinary terms with everyday idioms for a quick, cheesy laugh. 🍕😄'}, next=(), config={'configurable': {'thread_id': '1', 'checkpoint_ns': '', 'checkpoint_id': '1f19de96-a58b-6b48-8002-457e6c1fafa8'}}, metadata={'source': 'loop', 'step': 2, 'parents': {}}, created_at='2026-08-22T05:22:06.233684+00:00', parent_config={'configurable': {'thread_id': '1', 'checkpoint_ns': '', 'checkpoint_id': '1f19de96-9580-64fe-8001-5261fb8d6a31'}}, tasks=(), interrupts=()),
#  StateSnapshot(values={'topic': 'pizza', 'joke': 'Why did the pizza apply for a job?\n\nBecause it wanted to get a *slice* of the action and finally stop feeling so *crust*‑y! 🍕😄'}, next=('generate_explanation',), config={'configurable': {'thread_id': '1', 'checkpoint_ns': '', 'checkpoint_id': '1f19de96-9580-64fe-8001-5261fb8d6a31'}}, metadata={'source': 'loop', 'step': 1, 'parents': {}}, created_at='2026-08-22T05:22:04.551295+00:00', parent_config={'configurable': {'thread_id': '1', 'checkpoint_ns': '', 'checkpoint_id': '1f19de96-8c2b-63c0-8000-63fc26a081f2'}}, tasks=(PregelTask(id='1966f88d-844f-a97f-80a6-ea419ab3a848', name='generate_explanation', path=('__pregel_pull', 'generate_explanation'), error=None, interrupts=(), state=None, result={'explanation': '**What the joke is playing with**\n\n1. **“Slice of the action”**  \n   *Slice* is a literal part of a pizza (a piece you eat). In everyday English, “a slice of the action” is a playful way of saying “a share of what’s going on” or “a piece of the excitement.” The joke swaps the literal pizza‑slice meaning for the idiomatic expression, so the pizza “applies for a job” to get its own *slice* of the action.\n\n2. **“Crust‑y”**  \n   The word *crust* is the outer, baked part of a pizza. Adding the “‑y” makes the adjective *crust‑y*, which sounds like “crusty.” In slang, “crusty” can describe someone who’s rough, bitter, or a bit down‑and‑out. The joke pretends the pizza feels “crust‑y” (like it’s just a hard crust) and wants to stop feeling that way.\n\n3. **The overall picture**  \n   - **Why would a pizza look for a job?** Because it wants more than just being a tasty snack; it wants a “share” of something bigger—hence the “slice of the action.”  \n   - **Why does it want to stop feeling crust‑y?** It’s a pun on the pizza’s literal crust and the feeling of being “crusty” (unhappy or rough). By getting a job, the pizza hopes to become “fresh” and “full‑filled” rather than just a dry crust.\n\n4. **Why it’s funny**  \n   - **Personification:** The pizza is given human motives (looking for work, feeling emotions).  \n   - **Wordplay:** The punchline hinges on two puns—*slice* (both a pizza piece and a share) and *crust‑y* (both the pizza’s outer layer and a slang feeling).  \n   - **Surprise:** We expect a typical job‑related reason (money, experience), but the answer flips back to pizza‑specific language, catching the listener off‑guard in a light‑hearted way.\n\n**Bottom line:** The joke works because it treats a pizza like a person who wants a “slice” (share) of excitement and wants to stop being just a “crust‑y” (hard, bitter) piece—mixing culinary terms with everyday idioms for a quick, cheesy laugh. 🍕😄'}),), interrupts=()),
#  StateSnapshot(values={'topic': 'pizza'}, next=('generate_joke',), config={'configurable': {'thread_id': '1', 'checkpoint_ns': '', 'checkpoint_id': '1f19de96-8c2b-63c0-8000-63fc26a081f2'}}, metadata={'source': 'loop', 'step': 0, 'parents': {}}, created_at='2026-08-22T05:22:03.572729+00:00', parent_config={'configurable': {'thread_id': '1', 'checkpoint_ns': '', 'checkpoint_id': '1f19de96-8c26-65ab-bfff-467efc12b565'}}, tasks=(PregelTask(id='13301fe7-f790-387e-717c-c33a4c8e4af2', name='generate_joke', path=('__pregel_pull', 'generate_joke'), error=None, interrupts=(), state=None, result={'joke': 'Why did the pizza apply for a job?\n\nBecause it wanted to get a *slice* of the action and finally stop feeling so *crust*‑y! 🍕😄'}),), interrupts=()),
#  StateSnapshot(values={}, next=('__start__',), config={'configurable': {'thread_id': '1', 'checkpoint_ns': '', 'checkpoint_id': '1f19de96-8c26-65ab-bfff-467efc12b565'}}, metadata={'source': 'input', 'step': -1, 'parents': {}}, created_at='2026-08-22T05:22:03.570730+00:00', parent_config=None, tasks=(PregelTask(id='cecb4774-0721-039f-d0ea-aec39ff4446f', name='__start__', path=('__pregel_pull', '__start__'), error=None, interrupts=(), state=None, result={'topic': 'pizza'}),), interrupts=())]

# %%
config2={'configurable':{'thread_id':'2'}}
workflow.invoke({'topic':'pasta'},config=config2)
# Out:
# {'topic': 'pasta',
#  'joke': 'Why did the spaghetti get a promotion?  \n\nBecause it *pasta* way to success—always staying *al dente* and never getting tangled in office politics! 🍝😄',
#  'explanation': '**What the joke is saying**\n\n> *Why did the spaghetti get a promotion?*  \n> *Because it **pasta** way to success—always staying **al dente** and never getting tangled in office politics! 🍝😄*\n\n---\n\n### 1. The set‑up (the question)\n\n- **“Why did the spaghetti get a promotion?”**  \n  This frames the joke like a classic “Why did the chicken cross the road?” riddle. It makes us expect a punch‑line that explains a surprising or funny reason for a *spaghetti* (a piece of pasta) to climb the corporate ladder.\n\n---\n\n### 2. The punch‑line – breaking down the wordplay\n\n| Phrase in the punch‑line | What it literally means | Why it’s funny (the pun) |\n|--------------------------|------------------------|--------------------------|\n| **pasta** way to success | “Pasta” sounds exactly like “passed” (as in “passed the test” or “passed the interview”). | The listener expects a serious “path” or “road” to success, but we get a food‑related homophone. |\n| **al dente** | In Italian cooking, *al dente* means “to the tooth”—the ideal texture for pasta: firm, slightly chewy, not mushy. | In a workplace context, “staying al dente” is twisted to mean “staying firm, resilient, and not getting soft or slovenly.” |\n| **never getting tangled in office politics** | Spaghetti can get tangled on a plate, but here the joke flips it: the spaghetti *doesn’t* get tangled, implying it avoids the messy, back‑stabbing stuff that often drags people down at work. | It juxtaposes a literal spaghetti’s tendency to get tangled with the metaphorical “tangled” nature of office politics, highlighting the “spaghetti’s” good behavior. |\n\n---\n\n### 3. Why the joke works\n\n1. **Double meanings (puns)**  \n   - *Pasta* ↔ *passed*  \n   - *Al dente* ↔ *firm, resilient*  \n   The humor comes from swapping a culinary term for a corporate metaphor.\n\n2. **Surprise & Incongruity**  \n   We don’t expect a food item to have a career, so the mental image of a piece of spaghetti climbing a corporate ladder is absurd and therefore funny.\n\n3. **Relatability**  \n   Most people understand both the culinary phrase *al dente* and the concept of “office politics.” The joke lets us apply a familiar cooking rule to a workplace scenario, making the analogy click instantly.\n\n4. **Visual Imagery**  \n   The mind picture of a spaghetti strand standing tall, firm, and un‑twisted while coworkers (other noodles) are caught up in a messy “political” sauce adds a comedic visual layer.\n\n5. **Emoji reinforcement**  \n   The 🍝 emoji signals “spaghetti” and the 😄 emoji cues that the line is meant to be light‑hearted, nudging the reader toward a playful interpretation.\n\n---\n\n### 4. How you could explain it to someone who missed the wordplay\n\n> “The joke pretends that a piece of spaghetti can get a promotion at work. It says the spaghetti ‘pasta’ (sounds like ‘passed’) its way to success because it stays ‘al dente’—a cooking term meaning it stays firm and not too soft—so it never gets ‘tangled’ like other noodles might get in a messy office politics situation. The humor is all in the puns on ‘pasta’ and ‘al dente’ and the silly idea of a noodle navigating a corporate environment.”\n\n---\n\n### 5. Take‑away\n\n- **Core of the joke:** A series of food‑related puns (pasta/passed, al dente/firm) applied to a workplace metaphor (promotion, office politics).  \n- **Why it lands:** It blends two unrelated worlds (Italian cooking and corporate life) in a concise, clever way, creating a mental image that’s both absurd and instantly understandable.  \n\nSo the joke works because it turns ordinary culinary terms into a witty commentary on career success—*pasta* way to success, staying *al dente*, and staying out of the tangled mess of office politics! 🍝😄'}

# %%
workflow.get_state(config2)
# Out:
# StateSnapshot(values={'topic': 'pasta', 'joke': 'Why did the spaghetti get a promotion?  \n\nBecause it *pasta* way to success—always staying *al dente* and never getting tangled in office politics! 🍝😄', 'explanation': '**What the joke is saying**\n\n> *Why did the spaghetti get a promotion?*  \n> *Because it **pasta** way to success—always staying **al dente** and never getting tangled in office politics! 🍝😄*\n\n---\n\n### 1. The set‑up (the question)\n\n- **“Why did the spaghetti get a promotion?”**  \n  This frames the joke like a classic “Why did the chicken cross the road?” riddle. It makes us expect a punch‑line that explains a surprising or funny reason for a *spaghetti* (a piece of pasta) to climb the corporate ladder.\n\n---\n\n### 2. The punch‑line – breaking down the wordplay\n\n| Phrase in the punch‑line | What it literally means | Why it’s funny (the pun) |\n|--------------------------|------------------------|--------------------------|\n| **pasta** way to success | “Pasta” sounds exactly like “passed” (as in “passed the test” or “passed the interview”). | The listener expects a serious “path” or “road” to success, but we get a food‑related homophone. |\n| **al dente** | In Italian cooking, *al dente* means “to the tooth”—the ideal texture for pasta: firm, slightly chewy, not mushy. | In a workplace context, “staying al dente” is twisted to mean “staying firm, resilient, and not getting soft or slovenly.” |\n| **never getting tangled in office politics** | Spaghetti can get tangled on a plate, but here the joke flips it: the spaghetti *doesn’t* get tangled, implying it avoids the messy, back‑stabbing stuff that often drags people down at work. | It juxtaposes a literal spaghetti’s tendency to get tangled with the metaphorical “tangled” nature of office politics, highlighting the “spaghetti’s” good behavior. |\n\n---\n\n### 3. Why the joke works\n\n1. **Double meanings (puns)**  \n   - *Pasta* ↔ *passed*  \n   - *Al dente* ↔ *firm, resilient*  \n   The humor comes from swapping a culinary term for a corporate metaphor.\n\n2. **Surprise & Incongruity**  \n   We don’t expect a food item to have a career, so the mental image of a piece of spaghetti climbing a corporate ladder is absurd and therefore funny.\n\n3. **Relatability**  \n   Most people understand both the culinary phrase *al dente* and the concept of “office politics.” The joke lets us apply a familiar cooking rule to a workplace scenario, making the analogy click instantly.\n\n4. **Visual Imagery**  \n   The mind picture of a spaghetti strand standing tall, firm, and un‑twisted while coworkers (other noodles) are caught up in a messy “political” sauce adds a comedic visual layer.\n\n5. **Emoji reinforcement**  \n   The 🍝 emoji signals “spaghetti” and the 😄 emoji cues that the line is meant to be light‑hearted, nudging the reader toward a playful interpretation.\n\n---\n\n### 4. How you could explain it to someone who missed the wordplay\n\n> “The joke pretends that a piece of spaghetti can get a promotion at work. It says the spaghetti ‘pasta’ (sounds like ‘passed’) its way to success because it stays ‘al dente’—a cooking term meaning it stays firm and not too soft—so it never gets ‘tangled’ like other noodles might get in a messy office politics situation. The humor is all in the puns on ‘pasta’ and ‘al dente’ and the silly idea of a noodle navigating a corporate environment.”\n\n---\n\n### 5. Take‑away\n\n- **Core of the joke:** A series of food‑related puns (pasta/passed, al dente/firm) applied to a workplace metaphor (promotion, office politics).  \n- **Why it lands:** It blends two unrelated worlds (Italian cooking and corporate life) in a concise, clever way, creating a mental image that’s both absurd and instantly understandable.  \n\nSo the joke works because it turns ordinary culinary terms into a witty commentary on career success—*pasta* way to success, staying *al dente*, and staying out of the tangled mess of office politics! 🍝😄'}, next=(), c ...
